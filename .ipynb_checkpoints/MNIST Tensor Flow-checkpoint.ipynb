# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import scipy.linalg as splin
from matplotlib.patches import FancyArrowPatch
from mpl_toolkits.mplot3d import proj3d
from matplotlib.colors import LinearSegmentedColormap
import tensorflow as tf
import _pickle as pickle
from sklearn.manifold import TSNE
import scipy.linalg as splin

# %%
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets("MNIST_data/",one_hot=True)
# Out:
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz

# %%
def plotProjections(projections, clist, gridsize=2):
    xsize = 8
    ysize = 8
    figs, axs = plt.subplots(nrows = gridsize, ncols = gridsize, figsize=(4*xsize,4*ysize))
    for row in range(gridsize):
        for col in range(gridsize):
            if col >= row:
                if col == row:
                    sortIndex = row+2
                else:
                    sortIndex = row+1
                py = projections[:,row]
                px = projections[:,col+1]
                sorting = projections[:,sortIndex].argsort()
                
                CLIST = np.array(clist)[sorting]
                PX = px[sorting]
                PY = py[sorting]
                
                rangeX = PX.max() - PX.min()
                centerX = (PX.max() + PX.min())/2.0
                rangeY = PY.max() - PY.min()
                centerY = (PY.max() + PY.min())/2.0
                axesDist = 0.6*max(rangeX,rangeY)
                
                sc1 = axs[row,col].scatter(PX,PY,alpha=0.7,c=CLIST)
                
                subTitle = str(row+1) + ' vs. ' + str(col+2)
                
                axs[row,col].set_title(subTitle)
                axs[row,col].set_xlim([centerX - axesDist, centerX + axesDist])
                axs[row,col].set_ylim([centerY - axesDist, centerY + axesDist])
                axs[row,col].ticklabel_format(style='sci', scilimits=(-2,2),axis='both')
            else:
                axs[row,col].axis('off')
    plt.tight_layout()
    plt.show()

# %%
class Arrow3D(FancyArrowPatch):
    def __init__(self, xs, ys, zs, *args, **kwargs):
        FancyArrowPatch.__init__(self, (0,0), (0,0), *args, **kwargs)
        self._verts3d = xs, ys, zs

    def draw(self, renderer):
        xs3d, ys3d, zs3d = self._verts3d
        xs, ys, zs = proj3d.proj_transform(xs3d, ys3d, zs3d, renderer.M)
        self.set_positions((xs[0],ys[0]),(xs[1],ys[1]))
        FancyArrowPatch.draw(self, renderer)
        
def saveThing(thing,file):
    with open(file,'wb') as fil:
        pick = pickle.Pickler(fil)
        pick.dump(thing)
        pick.clear_memo()
        
def openThing(file,py2 = False):
    if py2:
        with open(file,'rb') as fil:
            u = pickle._Unpickler(fil)
            u.encoding = 'latin1'
            thing = u.load()
    else:
        with open(file,'rb') as fil:
            thing = pickle.load(fil)
    return thing

# %% [markdown]
# MNIST plots

# %%
def weight_variable(shape):
    initial = tf.truncated_normal(shape,stddev=0.1)
    return tf.Variable(initial)

def bias_variable(shape):
    initial = tf.constant(0.1,shape=shape)
    return tf.Variable(initial)

def conv2d(x,W):
    return tf.nn.conv2d(x,W,strides=[1,1,1,1],padding='SAME')

def max_pool_2x2(x):
    return tf.nn.max_pool(x,ksize=[1,2,2,1],strides=[1,2,2,1],padding='SAME')

# %%
x = tf.placeholder(tf.float32, shape=[None, 784])
y_ = tf.placeholder(tf.float32, shape=[None, 10])

W_conv1 = weight_variable([5,5,1,32])
b_conv1 = bias_variable([32])

x_image = tf.reshape(x,[-1,28,28,1])

h_conv1 = tf.nn.relu(conv2d(x_image,W_conv1)+b_conv1)
h_pool1 = max_pool_2x2(h_conv1)

W_conv2 = weight_variable([5,5,32,64])
b_conv2 = bias_variable([64])

h_conv2 = tf.nn.relu(conv2d(h_pool1,W_conv2) + b_conv2)
h_pool2 = max_pool_2x2(h_conv2)

W_fc1 = weight_variable([7*7*64,1024])
b_fc1 = bias_variable([1024])

h_pool2_flat = tf.reshape(h_pool2,[-1,7*7*64])
h_fc1 = tf.nn.relu(tf.matmul(h_pool2_flat,W_fc1) + b_fc1)

W_fc2 = weight_variable([1024,10])
b_fc2 = bias_variable([10])

keep_prob = tf.placeholder(tf.float32)
h_fc1_drop = tf.nn.dropout(h_fc1,keep_prob)

y_conv = tf.matmul(h_fc1_drop,W_fc2) + b_fc2

# %%
cross_entropy = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=y_, logits=y_conv))
train_step = tf.train.AdamOptimizer(1e-4).minimize(cross_entropy)
correct_prediction = tf.equal(tf.argmax(y_conv, 1), tf.argmax(y_, 1))
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

accuracies = []
allProbs = []

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    for i in range(5000):
        batch = mnist.train.next_batch(2000)
        if i % 10 == 0:
            train_accuracy = accuracy.eval(feed_dict={x: batch[0], y_: batch[1], keep_prob: 1.0})
            print('step %d, training accuracy %g' % (i, train_accuracy))
            accuracies.append([i, train_accuracy])
            if i % 100 == 0:
                probs_estimators = y_conv.eval(feed_dict={x: mnist.test.images, keep_prob:1.0},session=sess)
                allProbs.append(np.array([[np.exp(x)/sum([np.exp(y) for y in prob]) for x in prob] for prob in probs_estimators]))
        train_step.run(feed_dict={x: batch[0], y_: batch[1], keep_prob: 0.5})

    print('test accuracy %g' % accuracy.eval(feed_dict={x: mnist.test.images, y_: mnist.test.labels, keep_prob: 1.0}))
    probs_estimators = y_conv.eval(feed_dict={x: mnist.test.images, keep_prob:1.0},session=sess)
# Out:
# step 0, training accuracy 0.101
# step 10, training accuracy 0.28
# step 20, training accuracy 0.515
# step 30, training accuracy 0.7085
# step 40, training accuracy 0.7995
# step 50, training accuracy 0.8225
# step 60, training accuracy 0.854
# step 70, training accuracy 0.867
# step 80, training accuracy 0.8975
# step 90, training accuracy 0.901
# step 100, training accuracy 0.9145
# step 110, training accuracy 0.9195
# step 120, training accuracy 0.9205
# step 130, training accuracy 0.9255
# step 140, training accuracy 0.93
# step 150, training accuracy 0.927
# step 160, training accuracy 0.9405
# step 170, training accuracy 0.9345
# step 180, training accuracy 0.9415
# step 190, training accuracy 0.95
# step 200, training accuracy 0.9525
# step 210, training accuracy 0.949
# step 220, training accuracy 0.9445
# step 230, training accuracy 0.9535
# step 240, training accuracy 0.9485
# step 250, training accuracy 0.9515
# step 260, training accuracy 0.956
# step 270, training accuracy 0.961
# step 280, training accuracy 0.9635
# step 290, training accuracy 0.958
# step 300, training accuracy 0.9605
# step 310, training accuracy 0.9605
# step 320, training accuracy 0.966
# step 330, training accuracy 0.9625
# step 340, training accuracy 0.958
# step 350, training accuracy 0.965
# step 360, training accuracy 0.9715
# step 370, training accuracy 0.969
# step 380, training accuracy 0.966
# step 390, training accuracy 0.965
# step 400, training accuracy 0.969
# step 410, training accuracy 0.969
# step 420, training accuracy 0.968
# step 430, training accuracy 0.9765
# step 440, training accuracy 0.9685
# step 450, training accuracy 0.972
# step 460, training accuracy 0.9655
# step 470, training accuracy 0.9725
# step 480, training accuracy 0.972
# step 490, training accuracy 0.9675
# step 500, training accuracy 0.9765
# step 510, training accuracy 0.973
# step 520, training accuracy 0.976
# step 530, training accuracy 0.9705
# step 540, training accuracy 0.969
# step 550, training accuracy 0.9745
# step 560, training accuracy 0.9745
# step 570, training accuracy 0.9815
# step 580, training accuracy 0.976
# step 590, training accuracy 0.9845
# step 600, training accuracy 0.9775
# step 610, training accuracy 0.9755
# step 620, training accuracy 0.977
# step 630, training accuracy 0.9755
# step 640, training accuracy 0.978
# step 650, training accuracy 0.977
# step 660, training accuracy 0.98
# step 670, training accuracy 0.9785
# step 680, training accuracy 0.9825
# step 690, training accuracy 0.984
# step 700, training accuracy 0.978
# step 710, training accuracy 0.977
# step 720, training accuracy 0.9865
# step 730, training accuracy 0.9795
# step 740, training accuracy 0.982
# step 750, training accuracy 0.987
# step 760, training accuracy 0.98
# step 770, training accuracy 0.9825
# step 780, training accuracy 0.981
# step 790, training accuracy 0.9835
# step 800, training accuracy 0.988
# step 810, training accuracy 0.984
# step 820, training accuracy 0.988
# step 830, training accuracy 0.982
# step 840, training accuracy 0.9855
# step 850, training accuracy 0.9845
# step 860, training accuracy 0.9885
# step 870, training accuracy 0.9885
# step 880, training accuracy 0.983
# step 890, training accuracy 0.9835
# step 900, training accuracy 0.9855
# step 910, training accuracy 0.9895
# step 920, training accuracy 0.9875
# step 930, training accuracy 0.9855
# step 940, training accuracy 0.9875
# step 950, training accuracy 0.985
# step 960, training accuracy 0.985
# step 970, training accuracy 0.9885
# step 980, training accuracy 0.9875
# step 990, training accuracy 0.983
# step 1000, training accuracy 0.985
# step 1010, training accuracy 0.984
# step 1020, training accuracy 0.9845
# step 1030, training accuracy 0.985
# step 1040, training accuracy 0.9915
# step 1050, training accuracy 0.9865
# step 1060, training accuracy 0.9895
# step 1070, training accuracy 0.9845
# step 1080, training accuracy 0.983
# step 1090, training accuracy 0.9835
# step 1100, training accuracy 0.987
# step 1110, training accuracy 0.9875
# step 1120, training accuracy 0.988
# step 1130, training accuracy 0.9865
# step 1140, training accuracy 0.989
# step 1150, training accuracy 0.9865
# step 1160, training accuracy 0.988
# step 1170, training accuracy 0.9925
# step 1180, training accuracy 0.989
# step 1190, training accuracy 0.9885
# step 1200, training accuracy 0.988
# step 1210, training accuracy 0.9865
# step 1220, training accuracy 0.9895
# step 1230, training accuracy 0.988
# step 1240, training accuracy 0.991
# step 1250, training accuracy 0.989
# step 1260, training accuracy 0.9895
# step 1270, training accuracy 0.9905
# step 1280, training accuracy 0.9945
# step 1290, training accuracy 0.9915
# step 1300, training accuracy 0.9885
# step 1310, training accuracy 0.9925
# step 1320, training accuracy 0.991
# step 1330, training accuracy 0.991
# step 1340, training accuracy 0.991
# step 1350, training accuracy 0.993
# step 1360, training accuracy 0.9955
# step 1370, training accuracy 0.987
# step 1380, training accuracy 0.99
# step 1390, training accuracy 0.99
# step 1400, training accuracy 0.9905
# step 1410, training accuracy 0.9915
# step 1420, training accuracy 0.9895
# step 1430, training accuracy 0.9895
# step 1440, training accuracy 0.9935
# step 1450, training accuracy 0.9905
# step 1460, training accuracy 0.988
# step 1470, training accuracy 0.993
# step 1480, training accuracy 0.991
# step 1490, training accuracy 0.994
# step 1500, training accuracy 0.991
# step 1510, training accuracy 0.989
# step 1520, training accuracy 0.9935
# step 1530, training accuracy 0.9935
# step 1540, training accuracy 0.992
# step 1550, training accuracy 0.993
# step 1560, training accuracy 0.992
# step 1570, training accuracy 0.992
# step 1580, training accuracy 0.9915
# step 1590, training accuracy 0.996
# step 1600, training accuracy 0.995
# step 1610, training accuracy 0.9895
# step 1620, training accuracy 0.993
# step 1630, training accuracy 0.994
# step 1640, training accuracy 0.9935
# step 1650, training accuracy 0.995
# step 1660, training accuracy 0.994
# step 1670, training accuracy 0.9935
# step 1680, training accuracy 0.9955
# step 1690, training accuracy 0.993
# step 1700, training accuracy 0.995
# step 1710, training accuracy 0.995
# step 1720, training accuracy 0.9925
# step 1730, training accuracy 0.9925
# step 1740, training accuracy 0.9915
# step 1750, training accuracy 0.992
# step 1760, training accuracy 0.995
# step 1770, training accuracy 0.995
# step 1780, training accuracy 0.994
# step 1790, training accuracy 0.9945
# step 1800, training accuracy 0.992
# step 1810, training accuracy 0.994
# step 1820, training accuracy 0.995
# step 1830, training accuracy 0.994
# step 1840, training accuracy 0.9935
# step 1850, training accuracy 0.994
# step 1860, training accuracy 0.9975
# step 1870, training accuracy 0.994
# step 1880, training accuracy 0.9965
# step 1890, training accuracy 0.9935
# step 1900, training accuracy 0.9975
# step 1910, training accuracy 0.991
# step 1920, training accuracy 0.9925
# step 1930, training accuracy 0.995
# step 1940, training accuracy 0.9965
# step 1950, training accuracy 0.9975
# step 1960, training accuracy 0.9945
# step 1970, training accuracy 0.994
# step 1980, training accuracy 0.996
# step 1990, training accuracy 0.996
# step 2000, training accuracy 0.993
# step 2010, training accuracy 0.9915
# step 2020, training accuracy 0.997
# step 2030, training accuracy 0.997
# step 2040, training accuracy 0.997
# step 2050, training accuracy 0.9945
# step 2060, training accuracy 0.9945
# step 2070, training accuracy 0.9955
# step 2080, training accuracy 0.996
# step 2090, training accuracy 0.9975
# step 2100, training accuracy 0.9955
# step 2110, training accuracy 0.994
# step 2120, training accuracy 0.997
# step 2130, training accuracy 0.9955
# step 2140, training accuracy 0.9955
# step 2150, training accuracy 0.9935
# step 2160, training accuracy 0.9945
# step 2170, training accuracy 0.996
# step 2180, training accuracy 0.995
# step 2190, training accuracy 0.9965
# step 2200, training accuracy 0.9965
# step 2210, training accuracy 0.996
# step 2220, training accuracy 0.996
# step 2230, training accuracy 0.998
# step 2240, training accuracy 0.9955
# step 2250, training accuracy 0.996
# step 2260, training accuracy 0.9965
# step 2270, training accuracy 0.996
# step 2280, training accuracy 0.9995
# step 2290, training accuracy 0.997
# step 2300, training accuracy 0.9985
# step 2310, training accuracy 0.997
# step 2320, training accuracy 0.9935
# step 2330, training accuracy 0.9955
# step 2340, training accuracy 0.9945
# step 2350, training accuracy 0.9965
# step 2360, training accuracy 0.9975
# step 2370, training accuracy 0.996
# step 2380, training accuracy 0.9965
# step 2390, training accuracy 0.9985
# step 2400, training accuracy 0.998
# step 2410, training accuracy 0.996
# step 2420, training accuracy 0.998
# step 2430, training accuracy 0.999
# step 2440, training accuracy 0.997
# step 2450, training accuracy 0.997
# step 2460, training accuracy 0.997
# step 2470, training accuracy 0.9955
# step 2480, training accuracy 0.996
# step 2490, training accuracy 0.9995
# step 2500, training accuracy 0.999
# step 2510, training accuracy 0.9955
# step 2520, training accuracy 0.997
# step 2530, training accuracy 0.998
# step 2540, training accuracy 0.997
# step 2550, training accuracy 0.9985
# step 2560, training accuracy 0.998
# step 2570, training accuracy 0.997
# step 2580, training accuracy 0.997
# step 2590, training accuracy 0.9975
# step 2600, training accuracy 0.9995
# step 2610, training accuracy 0.9955
# step 2620, training accuracy 0.9985
# step 2630, training accuracy 0.9985
# step 2640, training accuracy 0.9975
# step 2650, training accuracy 0.998
# step 2660, training accuracy 0.9985
# step 2670, training accuracy 0.9955
# step 2680, training accuracy 0.9995
# step 2690, training accuracy 0.9985
# step 2700, training accuracy 0.9985
# step 2710, training accuracy 0.998
# step 2720, training accuracy 0.997
# step 2730, training accuracy 0.997
# step 2740, training accuracy 0.9985
# step 2750, training accuracy 0.9985
# step 2760, training accuracy 0.9985
# step 2770, training accuracy 0.999
# step 2780, training accuracy 0.999
# step 2790, training accuracy 0.997
# step 2800, training accuracy 0.9985
# step 2810, training accuracy 0.997
# step 2820, training accuracy 0.998
# step 2830, training accuracy 0.999
# step 2840, training accuracy 0.998
# step 2850, training accuracy 0.9985
# step 2860, training accuracy 0.998
# step 2870, training accuracy 0.9975
# step 2880, training accuracy 0.998
# step 2890, training accuracy 0.9985
# step 2900, training accuracy 0.9975
# step 2910, training accuracy 0.9985
# step 2920, training accuracy 0.997
# step 2930, training accuracy 0.999
# step 2940, training accuracy 0.999
# step 2950, training accuracy 0.998
# step 2960, training accuracy 0.9995
# step 2970, training accuracy 0.998
# step 2980, training accuracy 0.996
# step 2990, training accuracy 0.9985
# step 3000, training accuracy 0.9975
# step 3010, training accuracy 0.996
# step 3020, training accuracy 0.9975
# step 3030, training accuracy 0.9985
# step 3040, training accuracy 0.998
# step 3050, training accuracy 0.999
# step 3060, training accuracy 0.999
# step 3070, training accuracy 0.998
# step 3080, training accuracy 0.999
# step 3090, training accuracy 0.9985
# step 3100, training accuracy 0.997
# step 3110, training accuracy 0.999
# step 3120, training accuracy 0.999
# step 3130, training accuracy 0.998
# step 3140, training accuracy 0.999
# step 3150, training accuracy 0.999
# step 3160, training accuracy 0.998
# step 3170, training accuracy 0.9995
# step 3180, training accuracy 0.9965
# step 3190, training accuracy 0.9985
# step 3200, training accuracy 0.9995
# step 3210, training accuracy 0.9985
# step 3220, training accuracy 0.9995
# step 3230, training accuracy 1
# step 3240, training accuracy 0.9995
# step 3250, training accuracy 0.999
# step 3260, training accuracy 0.9985
# step 3270, training accuracy 0.9985
# step 3280, training accuracy 0.999
# step 3290, training accuracy 0.9995
# step 3300, training accuracy 0.999
# step 3310, training accuracy 0.999
# step 3320, training accuracy 1
# step 3330, training accuracy 1
# step 3340, training accuracy 0.999
# step 3350, training accuracy 0.9985
# step 3360, training accuracy 1
# step 3370, training accuracy 0.9995
# step 3380, training accuracy 0.9985
# step 3390, training accuracy 1
# step 3400, training accuracy 0.9995
# step 3410, training accuracy 0.998
# step 3420, training accuracy 0.999
# step 3430, training accuracy 0.999
# step 3440, training accuracy 0.999
# step 3450, training accuracy 0.999
# step 3460, training accuracy 0.9985
# step 3470, training accuracy 0.998
# step 3480, training accuracy 0.999
# step 3490, training accuracy 1
# step 3500, training accuracy 0.9995
# step 3510, training accuracy 0.9995
# step 3520, training accuracy 0.999
# step 3530, training accuracy 0.9985
# step 3540, training accuracy 0.999
# step 3550, training accuracy 0.999
# step 3560, training accuracy 0.998
# step 3570, training accuracy 0.9995
# step 3580, training accuracy 0.9995
# step 3590, training accuracy 0.999
# step 3600, training accuracy 0.9985
# step 3610, training accuracy 0.9995
# step 3620, training accuracy 0.999
# step 3630, training accuracy 0.9985
# step 3640, training accuracy 0.9995
# step 3650, training accuracy 1
# step 3660, training accuracy 0.9995
# step 3670, training accuracy 0.9995
# step 3680, training accuracy 0.9985
# step 3690, training accuracy 0.999
# step 3700, training accuracy 0.999
# step 3710, training accuracy 0.9995
# step 3720, training accuracy 1
# step 3730, training accuracy 1
# step 3740, training accuracy 1
# step 3750, training accuracy 0.9985
# step 3760, training accuracy 1
# step 3770, training accuracy 1
# step 3780, training accuracy 0.999
# step 3790, training accuracy 0.9995
# step 3800, training accuracy 0.9995
# step 3810, training accuracy 0.9995
# step 3820, training accuracy 0.999
# step 3830, training accuracy 1
# step 3840, training accuracy 1
# step 3850, training accuracy 0.999
# step 3860, training accuracy 1
# step 3870, training accuracy 0.998
# step 3880, training accuracy 0.9995
# step 3890, training accuracy 0.9995
# step 3900, training accuracy 1
# step 3910, training accuracy 0.999
# step 3920, training accuracy 1
# step 3930, training accuracy 0.9995
# step 3940, training accuracy 1
# step 3950, training accuracy 0.9995
# step 3960, training accuracy 0.9995
# step 3970, training accuracy 0.999
# step 3980, training accuracy 0.9995
# step 3990, training accuracy 1
# step 4000, training accuracy 0.9995
# step 4010, training accuracy 0.9995
# step 4020, training accuracy 1
# step 4030, training accuracy 1
# step 4040, training accuracy 1
# step 4050, training accuracy 0.9985
# step 4060, training accuracy 1
# step 4070, training accuracy 0.999
# step 4080, training accuracy 0.999
# step 4090, training accuracy 0.9995
# step 4100, training accuracy 1
# step 4110, training accuracy 0.9995
# step 4120, training accuracy 0.999
# step 4130, training accuracy 0.999
# step 4140, training accuracy 0.9995
# step 4150, training accuracy 0.9995
# step 4160, training accuracy 0.999
# step 4170, training accuracy 1
# step 4180, training accuracy 1
# step 4190, training accuracy 0.999
# step 4200, training accuracy 1
# step 4210, training accuracy 0.9995
# step 4220, training accuracy 0.9995
# step 4230, training accuracy 0.9995
# step 4240, training accuracy 1
# step 4250, training accuracy 1
# step 4260, training accuracy 1
# step 4270, training accuracy 0.999
# step 4280, training accuracy 0.9995
# step 4290, training accuracy 0.9995
# step 4300, training accuracy 1
# step 4310, training accuracy 0.9995
# step 4320, training accuracy 1
# step 4330, training accuracy 0.999
# step 4340, training accuracy 1
# step 4350, training accuracy 1
# step 4360, training accuracy 1
# step 4370, training accuracy 0.9995
# step 4380, training accuracy 1
# step 4390, training accuracy 1
# step 4400, training accuracy 1
# step 4410, training accuracy 1
# step 4420, training accuracy 1
# step 4430, training accuracy 1
# step 4440, training accuracy 1
# step 4450, training accuracy 0.9995
# step 4460, training accuracy 1
# step 4470, training accuracy 0.9995
# step 4480, training accuracy 1
# step 4490, training accuracy 1
# step 4500, training accuracy 0.9995
# step 4510, training accuracy 1
# step 4520, training accuracy 1
# step 4530, training accuracy 1
# step 4540, training accuracy 1
# step 4550, training accuracy 0.9995
# step 4560, training accuracy 1
# step 4570, training accuracy 1
# step 4580, training accuracy 1
# step 4590, training accuracy 1
# step 4600, training accuracy 0.9995
# step 4610, training accuracy 1
# step 4620, training accuracy 0.9995
# step 4630, training accuracy 0.9995
# step 4640, training accuracy 0.999
# step 4650, training accuracy 1
# step 4660, training accuracy 1
# step 4670, training accuracy 1
# step 4680, training accuracy 1
# step 4690, training accuracy 1
# step 4700, training accuracy 0.9995
# step 4710, training accuracy 0.999
# step 4720, training accuracy 1
# step 4730, training accuracy 1
# step 4740, training accuracy 1
# step 4750, training accuracy 1
# step 4760, training accuracy 1
# step 4770, training accuracy 1
# step 4780, training accuracy 1
# step 4790, training accuracy 1
# step 4800, training accuracy 1
# step 4810, training accuracy 1
# step 4820, training accuracy 0.9995
# step 4830, training accuracy 1
# step 4840, training accuracy 1
# step 4850, training accuracy 0.999
# step 4860, training accuracy 1
# step 4870, training accuracy 1
# step 4880, training accuracy 1
# step 4890, training accuracy 1
# step 4900, training accuracy 1
# step 4910, training accuracy 0.9995
# step 4920, training accuracy 0.9995
# step 4930, training accuracy 1
# step 4940, training accuracy 1
# step 4950, training accuracy 1
# step 4960, training accuracy 0.999
# step 4970, training accuracy 0.9995
# step 4980, training accuracy 1
# step 4990, training accuracy 1
# test accuracy 0.9916

# %%
saveThing(accuracies,'accuracies.pckl')

# %%
saveThing(allProbs,'allProbs.pckl')

# %%
plt.plot([x for x,y in accuracies],[1-y for x,y in accuracies])

plt.xticks([0,199,5000])

plt.grid()

#plt.yscale('log')

plt.show()

# %%
proj0,imCol0 = findProj(np.sqrt(allProbs[0]),eigs=4)
proj12,imCol2 = findProj(np.sqrt(allProbs[2]),eigs=4)
proj49,imCol49 = findProj(np.sqrt(allProbs[49]),eigs=4)

# %%
proj1,imCol1 = findProj(np.sqrt(allProbs[1]),eigs=4)

# %% [markdown]
# Plotting Data

# %%
probs = np.array([[np.exp(x)/sum([np.exp(y) for y in prob]) for x in prob] for prob in probs_estimators])

# %%
def findProj(data,eigs=4):
    data = np.array(data)
    DDT = np.log(np.dot(data,data.T))
    DDT_sums = np.array([sum(row)/len(data) for row in DDT])
    DDT_sum_sums = sum(DDT_sums)/len(data)
    DDT_PCA = np.array([[DDT[i][j] - DDT_sums[i] - DDT_sums[j] + DDT_sum_sums for i in range(len(data))] for j in range(len(data))])
    
    wR,vRt = splin.eigh(DDT_PCA,eigvals=(len(DDT)-1-eigs,len(DDT)-1))
    wI,vIt = splin.eigh(DDT_PCA,eigvals=(0,eigs))
    
    W = list(wR)
    W.extend(list(wI))
    W = np.array(W)
    sorting = abs(np.array(W)).argsort()[::-1]
    
    V = list(vRt.T)
    V.extend(list(vIt.T))
    V = np.array(V)
    
    W = W[sorting]
    V = V[sorting]
    
    imCol = []
    for i in range(len(W)):
        if W[i] < 0:
            imCol.append(i)
            
    proj = np.dot(V.T,np.diag(np.sqrt(np.abs(W))))
    
    return(proj,imCol)

# %%
proj,imCol = findProj(np.sqrt(probs),eigs=4)

# %%
saveThing(proj,'proj.pckl')
saveThing(probs,'probs.pckl')

# %%
colors = ['C'+str(i) for i in range(10)]
clist = []
labels = []
for label in mnist.test.labels:
    for e in range(10):
        if label[e] == 1:
            clist.append(colors[e])
            labels.append(e)
saveThing(labels,'labels.pckl')

# %%
#3D plots
px = proj[:,0]
py = proj[:,1]
pz = proj[:,2]

mean_x = px.min()
mean_y = py.min()
mean_z = pz.min()

Xdist = px.max() - px.min()
Xcntr = (px.max() + px.min())/2.0
Ydist = py.max() - py.min()
Ycntr = (py.max() + py.min())/2.0
Zdist = pz.max() - pz.min()
Zcntr = (pz.max() + pz.min())/2.0

dist = 0.5*max(Xdist,Ydist,Zdist)

fig = plt.figure(figsize = (10,10))
ax = fig.gca(projection='3d')
#ax.view_init(30,-60)

listTemp = [i for i in range(len(proj))]

ax.scatter(px,py,pz,c=clist,edgecolor='black',linewidth=0.2)

ax.set_xlim([Xcntr - dist, Xcntr + dist])
ax.set_ylim([Ycntr - dist, Ycntr + dist])
ax.set_zlim([Zcntr - dist, Zcntr + dist])

ax.set_xticks([])
ax.set_yticks([])
ax.set_zticks([])

arrowSize=2*dist/5

vects = [[mean_x+arrowSize,mean_y,mean_z],[mean_x,mean_y+arrowSize,mean_z],[mean_x,mean_y,mean_z+arrowSize]]

for v in vects:
    a = Arrow3D([mean_x,v[0]],[mean_y,v[1]],
                [mean_z,v[2]],mutation_scale=20,
                lw=3,arrowstyle="-|>",color="r")
    ax.add_artist(a)
ax.set_axis_off()

# %%
X = -2*np.log(np.dot(probs,probs.T))

# %%
X_embedded=TSNE(n_components=3).fit_transform(X)

# %%
sampleDigits = mnist.test.images[[3,2,1,30,19,15,21,0,61,16]]

# %%
for image in sampleDigits:
    plt.imshow([image[28*i:28*(i+1)] for i in range(28)],cmap='Greys')
    plt.xticks([])
    plt.yticks([])
    plt.show()

# %%
saveThing(sampleDigits,'sampleDigits.pckl')

# %%
probs = openThing('probs.pckl')
labels = openThing('labels.pckl')

# %%
def klDiv(p1,p2):
    return sum(p1*np.log(p1)-p1*np.log(p2) + p2*np.log(p2)-p2*np.log(p1))

# %%
distances = [[-8*np.log(np.dot(np.sqrt(p1),np.sqrt(p2))) for p1 in probs] for p2 in probs]

# %%
distances = abs(np.array(distances))

# %%
X_embedded = TSNE(n_components=3).fit_transform(distances)

# %%
klDistances = [[klDiv(p1,p2) for p1 in probs] for p2 in probs]

# %%
X_kl = TSNE(n_components=3).fit_transform(klDistances)

# %%
X_kl2D = TSNE(n_components=2).fit_transform(klDistances)

# %%
X_euclid = TSNE(n_components=3,init='pca').fit_transform(probs)

# %%
#3D plots
proj = X_kl2D

px = proj[:,0]
py = proj[:,1]
pz = proj[:,2]

mean_x = px.min()
mean_y = py.min()
mean_z = pz.min()

Xdist = px.max() - px.min()
Xcntr = (px.max() + px.min())/2.0
Ydist = py.max() - py.min()
Ycntr = (py.max() + py.min())/2.0
Zdist = pz.max() - pz.min()
Zcntr = (pz.max() + pz.min())/2.0

dist = 0.5*max(Xdist,Ydist,Zdist)

fig = plt.figure(figsize = (10,10))
ax = fig.gca(projection='3d')
#ax.view_init(30,-60)

ax.scatter(px,py,pz,c=clist,edgecolor='black',linewidth=0.2)

ax.set_xlim([Xcntr - dist, Xcntr + dist])
ax.set_ylim([Ycntr - dist, Ycntr + dist])
ax.set_zlim([Zcntr - dist, Zcntr + dist])

ax.set_xticks([])
ax.set_yticks([])
ax.set_zticks([])

plt.show()

# %%
saveThing(X_kl2D,'tsneKL2D.pckl')

# %%
plt.figure(figsize=(5,5))
plt.scatter(X_kl2D[:,0],X_kl2D[:,1],c=clist,edgecolor='black',linewidth=0.2)
plt.axis('equal')
plt.show()

# %%
plotProjections(proj0,clist,gridsize=4)

# %%
plotProjections(proj12,clist,gridsize=2)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.

# %%
plotProjections(proj49,clist,gridsize=4)

# %%
plt.scatter(proj1[:,1],proj1[:,2],c=clist)
plt.show()

# %%
plt.scatter(proj12[:,1],proj12[:,2],c=clist)
plt.show()

# %%
len(proj0)
# Out:
# 10000
